# %%
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import urllib
import requests
import numpy as np
import matplotlib.pyplot as plt
text=("access account activate activation alert amount assistant atm authorize auto automapyment autopay available balance bank banking bill billpay bot branch break down breakdown budget budgeting c.c. card cash cc charges chat chat bot chatbot check checking checks credit creditwise debit debt deposit deposited depositing dico due earn earning expenditure expenditures expenses fee fees finance finances fraud funds goal hack identity image improve keep late ledger loan locate location locator manage message messaging money monitor monitoring notification notifications order overdraft pay payment picture points pre-paid prepaid prepay protection quickpay rating report reward rewards saving savings scan schedule score secure send sms spend spending statement stolen suspicious teller theft track tracking transfer transferring trend unauthorized wire zelle")
mask = np.array(Image.open("key1.jpg"))
wordcloud_spa = WordCloud(background_color="black", max_words=1000, mask=mask).generate(text)

# create coloring from image
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[7,6])
plt.imshow(wordcloud_spa.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.show()
